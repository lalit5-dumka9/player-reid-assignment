# %%
pip install opencv-python torch ultralytics scikit-learn numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (4.10.0.84)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: torch in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (2.5.1)
# Collecting ultralytics
#   Using cached ultralytics-8.3.165-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: scikit-learn in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (1.26.4)
# Requirement already satisfied: filelock in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from ultralytics) (0.20.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from ultralytics) (4.67.0)
# Requirement already satisfied: psutil in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from ultralytics) (6.1.0)
# Collecting py-cpuinfo (from ultralytics)
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from ultralytics) (2.2.3)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\lalit\anaconda3\envs\tf\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Downloading ultralytics-8.3.165-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ------------------------------ --------- 0.8/1.0 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 5.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, ultralytics-thop, ultralytics
# Successfully installed py-cpuinfo-9.0.0 ultralytics-8.3.165 ultralytics-thop-2.0.14

# %%
import cv2
import torch
from ultralytics import YOLO
import numpy as np
from utils import extract_features, match_players, draw_player_boxes

# Load model
model = YOLO('weights/best.pt')  # Replace with actual model name if different

# Load videos
broadcast_path = 'data/broadcast.mp4'
tacticam_path = 'data/tacticam.mp4'

cap_broadcast = cv2.VideoCapture(broadcast_path)
cap_tacticam = cv2.VideoCapture(tacticam_path)

player_feats_broadcast = {}
player_feats_tacticam = {}

print("\n[INFO] Processing Broadcast Video...")
frame_id = 0
while True:
    ret, frame = cap_broadcast.read()
    if not ret or frame_id > 100:
        break

    results = model(frame)[0]  # assume single model inference
    for box in results.boxes:
        cls = int(box.cls[0])
        if cls != 0:  # Assuming class 0 = player
            continue
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        crop = frame[y1:y2, x1:x2]
        feat = extract_features(crop)
        player_feats_broadcast[f"b_{frame_id}_{x1}"] = feat
    frame_id += 1

print("[INFO] Processing Tacticam Video...")
cap_tacticam.set(cv2.CAP_PROP_POS_FRAMES, 0)
frame_id = 0
while True:
    ret, frame = cap_tacticam.read()
    if not ret or frame_id > 100:
        break

    results = model(frame)[0]
    for box in results.boxes:
        cls = int(box.cls[0])
        if cls != 0:
            continue
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        crop = frame[y1:y2, x1:x2]
        feat = extract_features(crop)
        player_feats_tacticam[f"t_{frame_id}_{x1}"] = feat
    frame_id += 1

# Match players
print("[INFO] Matching players across cameras...")
matches = match_players(player_feats_broadcast, player_feats_tacticam)

# Output
print("\nMatched Players:")
for b_id, t_id in matches.items():
    print(f"Broadcast ID: {b_id} <--> Tacticam ID: {t_id}")

cap_broadcast.release()
cap_tacticam.release()
cv2.destroyAllWindows()
# Out:
# [INFO] Processing Broadcast Video...
#
# 0: 384x640 3 players, 598.3ms
# Speed: 10.0ms preprocess, 598.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 544.1ms
# Speed: 2.6ms preprocess, 544.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 players, 534.6ms
# Speed: 1.7ms preprocess, 534.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 608.3ms
# Speed: 4.4ms preprocess, 608.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 players, 513.1ms
# Speed: 2.3ms preprocess, 513.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 506.3ms
# Speed: 1.9ms preprocess, 506.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 551.8ms
# Speed: 2.0ms preprocess, 551.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 14 players, 1 referee, 566.0ms
# Speed: 2.2ms preprocess, 566.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 522.4ms
# Speed: 2.2ms preprocess, 522.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 594.6ms
# Speed: 2.0ms preprocess, 594.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 560.6ms
# Speed: 2.4ms preprocess, 560.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1 referee, 520.3ms
# Speed: 1.8ms preprocess, 520.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 510.7ms
# Speed: 1.7ms preprocess, 510.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 518.6ms
# Speed: 2.0ms preprocess, 518.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 3 referees, 594.3ms
# Speed: 7.3ms preprocess, 594.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 601.1ms
# Speed: 2.6ms preprocess, 601.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 532.5ms
# Speed: 2.0ms preprocess, 532.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 558.8ms
# Speed: 1.9ms preprocess, 558.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 2 referees, 548.3ms
# Speed: 1.9ms preprocess, 548.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 505.8ms
# Speed: 2.5ms preprocess, 505.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 510.2ms
# Speed: 1.9ms preprocess, 510.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 506.7ms
# Speed: 1.8ms preprocess, 506.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 539.5ms
# Speed: 1.8ms preprocess, 539.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 538.5ms
# Speed: 2.3ms preprocess, 538.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 542.9ms
# Speed: 2.3ms preprocess, 542.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 560.1ms
# Speed: 1.9ms preprocess, 560.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2 referees, 512.5ms
# Speed: 1.9ms preprocess, 512.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2 referees, 555.4ms
# Speed: 1.8ms preprocess, 555.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 552.2ms
# Speed: 2.4ms preprocess, 552.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 2 referees, 550.8ms
# Speed: 2.6ms preprocess, 550.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 537.7ms
# Speed: 1.9ms preprocess, 537.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 3 referees, 536.5ms
# Speed: 1.6ms preprocess, 536.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 531.1ms
# Speed: 2.4ms preprocess, 531.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 534.2ms
# Speed: 2.0ms preprocess, 534.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 583.9ms
# Speed: 2.1ms preprocess, 583.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 561.8ms
# Speed: 1.9ms preprocess, 561.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 533.1ms
# Speed: 2.9ms preprocess, 533.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 572.0ms
# Speed: 2.2ms preprocess, 572.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 665.3ms
# Speed: 1.9ms preprocess, 665.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 586.2ms
# Speed: 2.0ms preprocess, 586.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1 referee, 580.4ms
# Speed: 2.6ms preprocess, 580.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 590.3ms
# Speed: 2.7ms preprocess, 590.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1 referee, 595.4ms
# Speed: 1.7ms preprocess, 595.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 578.5ms
# Speed: 1.7ms preprocess, 578.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1 referee, 596.2ms
# Speed: 2.4ms preprocess, 596.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1 referee, 541.1ms
# Speed: 1.9ms preprocess, 541.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 565.2ms
# Speed: 2.1ms preprocess, 565.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1 referee, 618.5ms
# Speed: 1.7ms preprocess, 618.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1 referee, 561.1ms
# Speed: 3.1ms preprocess, 561.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 603.6ms
# Speed: 1.9ms preprocess, 603.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 649.9ms
# Speed: 2.3ms preprocess, 649.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 12 players, 586.9ms
# Speed: 2.0ms preprocess, 586.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 634.7ms
# Speed: 2.5ms preprocess, 634.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 586.5ms
# Speed: 3.4ms preprocess, 586.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1 referee, 661.3ms
# Speed: 2.5ms preprocess, 661.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 2 referees, 564.4ms
# Speed: 1.9ms preprocess, 564.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 2 referees, 563.3ms
# Speed: 2.1ms preprocess, 563.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2 referees, 545.2ms
# Speed: 1.8ms preprocess, 545.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2 referees, 562.9ms
# Speed: 2.4ms preprocess, 562.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 3 referees, 557.8ms
# Speed: 1.7ms preprocess, 557.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 2 referees, 554.2ms
# Speed: 2.1ms preprocess, 554.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 3 referees, 562.2ms
# Speed: 1.8ms preprocess, 562.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1 referee, 551.5ms
# Speed: 1.9ms preprocess, 551.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 584.0ms
# Speed: 2.0ms preprocess, 584.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 604.2ms
# Speed: 2.7ms preprocess, 604.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2 referees, 539.6ms
# Speed: 2.4ms preprocess, 539.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1 referee, 600.1ms
# Speed: 1.9ms preprocess, 600.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 2 referees, 649.8ms
# Speed: 18.3ms preprocess, 649.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 2 referees, 643.0ms
# Speed: 2.6ms preprocess, 643.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1 referee, 553.2ms
# Speed: 1.9ms preprocess, 553.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee,
2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 581.3ms
# Speed: 3.7ms preprocess, 581.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 545.5ms
# Speed: 2.1ms preprocess, 545.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 592.0ms
# Speed: 1.8ms preprocess, 592.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 611.4ms
# Speed: 1.9ms preprocess, 611.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 556.9ms
# Speed: 2.1ms preprocess, 556.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 559.9ms
# Speed: 1.8ms preprocess, 559.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 727.1ms
# Speed: 2.1ms preprocess, 727.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 591.1ms
# Speed: 4.6ms preprocess, 591.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 517.2ms
# Speed: 2.1ms preprocess, 517.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 590.9ms
# Speed: 2.1ms preprocess, 590.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 525.3ms
# Speed: 1.6ms preprocess, 525.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 540.3ms
# Speed: 2.5ms preprocess, 540.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 527.9ms
# Speed: 1.9ms preprocess, 527.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 556.5ms
# Speed: 1.7ms preprocess, 556.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 3 referees, 825.4ms
# Speed: 2.0ms preprocess, 825.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 694.1ms
# Speed: 2.3ms preprocess, 694.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 533.8ms
# Speed: 2.3ms preprocess, 533.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Matching players across cameras...
#
# Matched Players:
# Broadcast ID: b_7_1442 <--> Tacticam ID: t_59_654
# Broadcast ID: b_8_1447 <--> Tacticam ID: t_59_654
# Broadcast ID: b_9_1453 <--> Tacticam ID: t_32_586
# Broadcast ID: b_10_1460 <--> Tacticam ID: t_60_656
# Broadcast ID: b_11_1466 <--> Tacticam ID: t_60_656
# Broadcast ID: b_17_1502 <--> Tacticam ID: t_42_607
# Broadcast ID: b_18_1649 <--> Tacticam ID: t_7_586
# Broadcast ID: b_22_1515 <--> Tacticam ID: t_30_583
# Broadcast ID: b_23_1518 <--> Tacticam ID: t_42_607
# Broadcast ID: b_24_1519 <--> Tacticam ID: t_30_583
# Broadcast ID: b_25_1519 <--> Tacticam ID: t_30_583
# Broadcast ID: b_26_1519 <--> Tacticam ID: t_30_583
# Broadcast ID: b_27_1519 <--> Tacticam ID: t_30_583
# Broadcast ID: b_28_1519 <--> Tacticam ID: t_31_583
# Broadcast ID: b_29_1519 <--> Tacticam ID: t_42_607
# Broadcast ID: b_30_1519 <--> Tacticam ID: t_30_583
# Broadcast ID: b_33_1513 <--> Tacticam ID: t_32_586
# Broadcast ID: b_37_741 <--> Tacticam ID: t_81_258
# Broadcast ID: b_41_785 <--> Tacticam ID: t_81_258
# Broadcast ID: b_45_831 <--> Tacticam ID: t_81_258
# Broadcast ID: b_48_863 <--> Tacticam ID: t_81_258
# Broadcast ID: b_50_886 <--> Tacticam ID: t_81_258
# Broadcast ID: b_63_578 <--> Tacticam ID: t_81_258
# Broadcast ID: b_68_976 <--> Tacticam ID: t_38_598
# Broadcast ID: b_70_1329 <--> Tacticam ID: t_81_258
# Broadcast ID: b_71_1286 <--> Tacticam ID: t_59_654
# Broadcast ID: b_72_1250 <--> Tacticam ID: t_36_594
# Broadcast ID: b_75_1138 <--> Tacticam ID: t_37_595
# Broadcast ID: b_79_1016 <--> Tacticam ID: t_59_654
# Broadcast ID: b_82_1186 <--> Tacticam ID: t_81_258
# Broadcast ID: b_83_1203 <--> Tacticam ID: t_81_258
# Broadcast ID: b_84_1222 <--> Tacticam ID: t_81_258
# Broadcast ID: b_84_905 <--> Tacticam ID: t_30_583
# Broadcast ID: b_87_850 <--> Tacticam ID: t_38_598
